# %%
'''To carry out a PCA analysis in Python'''
'''imports a million things'''
import pyfits
import matplotlib.pyplot as plt

import heapq
import pyfits
import matplotlib as plt
from pylab import *
import numpy as np
from decimal import *
import numpy
from scipy.optimize import curve_fit
from scipy.integrate import quad
import matplotlib.pyplot as plt
from astropy.modeling import models, fitting
from pylab import *
from scipy import stats
from scipy.stats import chisquare
import matplotlib.patches as patches
from astropy.io import fits


from astropy.cosmology import WMAP9 as cosmo

import pyfits
import matplotlib.pyplot as plt

import heapq
import pyfits
import matplotlib as plt
from pylab import *
import numpy as np
from decimal import *
import numpy
from scipy.optimize import curve_fit
from scipy.integrate import quad
import matplotlib.pyplot as plt
from astropy.modeling import models, fitting
from pylab import *
from scipy import stats
from scipy.stats import chisquare
import matplotlib.patches as patches

import sys 

import numpy as np
from scipy.ndimage.filters import maximum_filter
from scipy.ndimage.morphology import generate_binary_structure, binary_erosion
import matplotlib.pyplot as pp
from scipy.ndimage import iterate_structure

sys.path.append('/usr/local/lib/python2.7/site-packages/ppxf')
sys.path

from __future__ import print_function

from astropy.io import fits
import numpy as np
import glob
from time import clock
from os import path

from ppxf import ppxf
import ppxf_util as util
plt.clf()

from astropy.convolution import convolve, convolve_fft
import matplotlib.pyplot as plt
from astropy.convolution import Gaussian2DKernel
from astropy.convolution import Gaussian1DKernel
from astropy.convolution import convolve

import scipy.ndimage.filters as filters
from scipy import ndimage
from scipy.stats import norm

#os.chdir(os.path.expanduser('~/Documents/LAURA_SIMS'))

import photutils
import os

# %%
'''PCA_img.txt'''
import pandas as pd

feature_dict = {i:label for i,label in zip(
                range(4),
                  ('sepal length in cm',
                  'sepal width in cm',
                  'petal length in cm',
                  'petal width in cm', ))}

df = pd.io.parsers.read_csv(
    filepath_or_buffer='https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data',
    header=None,
    sep=',',
    )
df.columns = [l for i,l in sorted(feature_dict.items())] + ['class label']
df.dropna(how="all", inplace=True) # to drop the empty line at file-end

df.tail()
# Out:
#      sepal length in cm  sepal width in cm  petal length in cm  \
# 145                 6.7                3.0                 5.2
# 146                 6.3                2.5                 5.0
# 147                 6.5                3.0                 5.2
# 148                 6.2                3.4                 5.4
# 149                 5.9                3.0                 5.1
#
#      petal width in cm     class label
# 145                2.3  Iris-virginica
# 146                1.9  Iris-virginica
# 147                2.0  Iris-virginica
# 148                2.3  Iris-virginica
# 149                1.8  Iris-virginica

# %%
from sklearn.preprocessing import LabelEncoder

X = df[['sepal length in cm', 'sepal width in cm', 'petal length in cm', 'petal width in cm']].values
y = df['class label'].values

enc = LabelEncoder()
label_encoder = enc.fit(y)
y = label_encoder.transform(y) + 1

label_dict = {1: 'Setosa', 2: 'Versicolor', 3:'Virginica'}

# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import math

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12,6))

for ax,cnt in zip(axes.ravel(), range(4)):  

    # set bin sizes
    print(X[:,cnt])
    min_b = math.floor(np.min(X[:,cnt]))
    max_b = math.ceil(np.max(X[:,cnt]))
    bins = np.linspace(min_b, max_b, 25)

    # plottling the histograms
    for lab,col in zip(range(1,4), ('blue', 'red', 'green')):
        ax.hist(X[y==lab, cnt],
                   color=col,
                   label='class %s' %label_dict[lab],
                   bins=bins,
                   alpha=0.5,)
    ylims = ax.get_ylim()

    # plot annotation
    leg = ax.legend(loc='upper right', fancybox=True, fontsize=8)
    leg.get_frame().set_alpha(0.5)
    ax.set_ylim([0, max(ylims)+2])
    ax.set_xlabel(feature_dict[cnt])
    ax.set_title('Iris histogram #%s' %str(cnt+1))

    # hide axis ticks
    ax.tick_params(axis="both", which="both", bottom="off", top="off",  
            labelbottom="on", left="off", right="off", labelleft="on")

    # remove axis spines
    ax.spines["top"].set_visible(False)  
    ax.spines["right"].set_visible(False)
    ax.spines["bottom"].set_visible(False)
    ax.spines["left"].set_visible(False)    

axes[0][0].set_ylabel('count')
axes[1][0].set_ylabel('count')

fig.tight_layout()       

plt.show()
# Out:
# [ 5.1  4.9  4.7  4.6  5.   5.4  4.6  5.   4.4  4.9  5.4  4.8  4.8  4.3  5.8
#   5.7  5.4  5.1  5.7  5.1  5.4  5.1  4.6  5.1  4.8  5.   5.   5.2  5.2  4.7
#   4.8  5.4  5.2  5.5  4.9  5.   5.5  4.9  4.4  5.1  5.   4.5  4.4  5.   5.1
#   4.8  5.1  4.6  5.3  5.   7.   6.4  6.9  5.5  6.5  5.7  6.3  4.9  6.6  5.2
#   5.   5.9  6.   6.1  5.6  6.7  5.6  5.8  6.2  5.6  5.9  6.1  6.3  6.1  6.4
#   6.6  6.8  6.7  6.   5.7  5.5  5.5  5.8  6.   5.4  6.   6.7  6.3  5.6  5.5
#   5.5  6.1  5.8  5.   5.6  5.7  5.7  6.2  5.1  5.7  6.3  5.8  7.1  6.3  6.5
#   7.6  4.9  7.3  6.7  7.2  6.5  6.4  6.8  5.7  5.8  6.4  6.5  7.7  7.7  6.
#   6.9  5.6  7.7  6.3  6.7  7.2  6.2  6.1  6.4  7.2  7.4  7.9  6.4  6.3  6.1
#   7.7  6.3  6.4  6.   6.9  6.7  6.9  5.8  6.8  6.7  6.7  6.3  6.5  6.2  5.9]
# [ 3.5  3.   3.2  3.1  3.6  3.9  3.4  3.4  2.9  3.1  3.7  3.4  3.   3.   4.
#   4.4  3.9  3.5  3.8  3.8  3.4  3.7  3.6  3.3  3.4  3.   3.4  3.5  3.4  3.2
# ...

# %%
np.set_printoptions(precision=4)

mean_vectors = []

for cl in range(1,4):
    print('cl', cl, 'X[cl]', X[y==cl])
    mean_vectors.append(np.mean(X[y==cl], axis=0))
    print('Mean Vector class %s: %s\n' %(cl, mean_vectors[cl-1]))
# Out:
# cl 1 X[cl] [[ 5.1  3.5  1.4  0.2]
#  [ 4.9  3.   1.4  0.2]
#  [ 4.7  3.2  1.3  0.2]
#  [ 4.6  3.1  1.5  0.2]
#  [ 5.   3.6  1.4  0.2]
#  [ 5.4  3.9  1.7  0.4]
#  [ 4.6  3.4  1.4  0.3]
#  [ 5.   3.4  1.5  0.2]
#  [ 4.4  2.9  1.4  0.2]
#  [ 4.9  3.1  1.5  0.1]
#  [ 5.4  3.7  1.5  0.2]
#  [ 4.8  3.4  1.6  0.2]
#  [ 4.8  3.   1.4  0.1]
#  [ 4.3  3.   1.1  0.1]
#  [ 5.8  4.   1.2  0.2]
#  [ 5.7  4.4  1.5  0.4]
#  [ 5.4  3.9  1.3  0.4]
#  [ 5.1  3.5  1.4  0.3]
#  [ 5.7  3.8  1.7  0.3]
#  [ 5.1  3.8  1.5  0.3]
#  [ 5.4  3.4  1.7  0.2]
#  [ 5.1  3.7  1.5  0.4]
#  [ 4.6  3.6  1.   0.2]
#  [ 5.1  3.3  1.7  0.5]
#  [ 4.8  3.4  1.9  0.2]
#  [ 5.   3.   1.6  0.2]
#  [ 5.   3.4  1.6  0.4]
#  [ 5.2  3.5  1.5  0.2]
#  [ 5.2  3.4  1.4  0.2]
#  [ 4.7  3.2  1.6  0.2]
#  [ 4.8  3.1  1.6  0.2]
#  [ 5.4  3.4  1.5  0.4]
#  [ 5.2  4.1  1.5  0.1]
#  [ 5.5  4.2  1.4  0.2]
#  [ 4.9  3.1  1.5  0.1]
#  [ 5.   3.2  1.2  0.2]
#  [ 5.5  3.5  1.3  0.2]
#  [ 4.9  3.1  1.5  0.1]
#  [ 4.4  3.   1.3  0.2]
# ...

# %%
'''Now my data frame, actually going to do an LDA first :)'''

# %%
import pandas as pd

feature_dict = {i:label for i,label in zip(
                range(11),
                  ('Counter',
                  'Image',
                  'class label',
                  'Myr',
                  'Viewpoint',
                  'Gini',
                  'M20',
                  'Concentration (C)',
                  'Asymmetry (A)',
                  'Clumpiness (S)',
                  'Sersic N',
                  'Shape Asymmetry (A_S)'))}
print(feature_dict)
#Counter	Image	Merger (0 = no, 1 = yes)	Myr	Viewpoint	Gini	M20	C	A	S	Sersic n
'''view=0
df = pd.io.parsers.read_table(
    filepath_or_buffer='PCA_img_0.txt',
    header=[0],
    sep='\t', skiprows=14*view,nrows=14
    )#,skiprows=10,nrows=10'''
myr=250#5,200,180,185,190,195,205,210,220,225,230,240,250
df = pd.io.parsers.read_table(
    filepath_or_buffer='PCA_img_0.txt',
    header=[0],
    sep='\t'
    )#,skiprows=10,nrows=10
#df=df.loc[df['Myr'] == 5 or df['Myr'] == 225]
df=df.loc[df['Myr'].isin([5,200,myr])]
df.columns = [l for i,l in sorted(feature_dict.items())] + ['Shape Asymmetry']
df.dropna(how="all", inplace=True) # to drop the empty line at file-end

#df.tail()
print(df)
# Out:
# {0: 'Counter', 1: 'Image', 2: 'class label', 3: 'Myr', 4: 'Viewpoint', 5: 'Gini', 6: 'M20', 7: 'Concentration (C)', 8: 'Asymmetry (A)', 9: 'Clumpiness (S)', 10: 'Sersic N'}
#     Counter                                              Image  class label  \
# 0         0  m0.5_fg0.3_allrx10_isolated_sunruns/hires_kin/...            0
# 1         1  m0.5_fg0.3_allrx10_isolated_sunruns/hires_kin/...            0
# 12       12  q0.5_fg0.3_allrx10_sunruns/hires_kin/broadband...            1
# 14       14  m0.5_fg0.3_allrx10_isolated_sunruns/hires_kin/...            0
# 15       15  m0.5_fg0.3_allrx10_isolated_sunruns/hires_kin/...            0
# 26       26  q0.5_fg0.3_allrx10_sunruns/hires_kin/broadband...            1
# 28       28  m0.5_fg0.3_allrx10_isolated_sunruns/hires_kin/...            0
# 29       29  m0.5_fg0.3_allrx10_isolated_sunruns/hires_kin/...            0
# 40       40  q0.5_fg0.3_allrx10_sunruns/hires_kin/broadband...            1
# ...

# %%
from sklearn.preprocessing import LabelEncoder

X = df[['Gini','M20','Concentration (C)', 'Asymmetry (A)', 'Clumpiness (S)', 'Sersic N', 'Shape Asymmetry']].values

y = df['class label'].values

enc = LabelEncoder()
label_encoder = enc.fit(y)
y = label_encoder.transform(y) + 1

label_dict = {1: 'NonMerger', 2: 'Merger'}

# %%
# %matplotlib inline

# %%
from matplotlib import pyplot as plt
import numpy as np
import math
print(label_dict)
fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(18,22))

for ax,cnt in zip(axes.ravel(), range(7)):  
    
    
    min_b = math.floor(np.min(X[:,cnt]))
    max_b = math.ceil(np.max(X[:,cnt]))
    bins = np.linspace(min_b, max_b, 25)

    # plottling the histograms
    for lab,col in zip(range(1,7), ('blue', 'red')):
        ax.hist(X[y==lab, cnt],
                   color=col,
                   label='class %s' %label_dict[lab],
                   bins=bins,
                   alpha=0.5,)
    ylims = ax.get_ylim()

    # plot annotation
    leg = ax.legend(loc='upper right', fancybox=True, fontsize=8)
    leg.get_frame().set_alpha(0.5)
    ax.set_ylim([0, max(ylims)+2])
    
    if cnt==6:
        ax.set_xlabel('Shape Asymmetry')
    else:
        ax.set_xlabel(feature_dict[cnt+5])
    #ax.set_xlabel(feature_dict[cnt+6])
    ax.set_title('Histogram #%s' %str(cnt))

    # hide axis ticks
    ax.tick_params(axis="both", which="both", bottom="off", top="off",  
            labelbottom="on", left="off", right="off", labelleft="on")

    # remove axis spines
    ax.spines["top"].set_visible(False)  
    ax.spines["right"].set_visible(False)
    ax.spines["bottom"].set_visible(False)
    ax.spines["left"].set_visible(False)    

axes[0][0].set_ylabel('count')
axes[1][0].set_ylabel('count')

fig.tight_layout()       
plt.savefig('../MaNGA_Papers/Paper_I/LDA_initial_hist_gyr_'+str(myr)+'.pdf')
#plt.show()
# Out:
# {1: 'NonMerger', 2: 'Merger'}

# %%
np.set_printoptions(precision=4)

mean_vectors = []
for cl in range(1,3):
    #print('cl', cl, 'X[cl]', X[y==cl])
    mean_vectors.append(np.mean(X[y==cl], axis=0))
    print('Mean Vector class %s: %s\n' %(cl, mean_vectors[cl-1]))
# Out:
# Mean Vector class 1: [ 0.7925 -1.9663  3.039   0.1662  0.2042  1.2926  0.105 ]
#
# Mean Vector class 2: [ 0.7374 -2.3215  4.7068  0.2357  0.1044  2.0685  0.2782]

# %%
from sklearn.decomposition import PCA as sklearnPCA

sklearn_pca = sklearnPCA(n_components=2)
X_pca = sklearn_pca.fit_transform(X)

def plot_pca():

    ax = plt.subplot(111)

    for label,marker,color in zip(
        range(1,4),('^', 's'),('blue', 'red')):

        plt.scatter(x=X_pca[:,0][y == label],
                y=X_pca[:,1][y == label],
                marker=marker,
                color=color,
                alpha=0.5,
                label=label_dict[label]
                )

    plt.xlabel('PC1')
    plt.ylabel('PC2')

    leg = plt.legend(loc='upper right', fancybox=True)
    leg.get_frame().set_alpha(0.5)
    plt.title('PCA: Merger projection onto the first 2 principal components')

    # hide axis ticks
    plt.tick_params(axis="both", which="both", bottom="off", top="off",  
            labelbottom="on", left="off", right="off", labelleft="on")

    # remove axis spines
    ax.spines["top"].set_visible(False)  
    ax.spines["right"].set_visible(False)
    ax.spines["bottom"].set_visible(False)
    ax.spines["left"].set_visible(False)    

    plt.tight_layout
    plt.grid()

    plt.show()

    
S_W = np.zeros((7,7))
for cl,mv in zip(range(1,7), mean_vectors):
    class_sc_mat = np.zeros((7,7))                  # scatter matrix for every class
    for row in X[y == cl]:
        row, mv = row.reshape(7,1), mv.reshape(7,1) # make column vectors
        class_sc_mat += (row-mv).dot((row-mv).T)
    S_W += class_sc_mat                             # sum class scatter matrices
print('within-class Scatter Matrix:\n', S_W)
overall_mean = np.mean(X, axis=0)

S_B = np.zeros((7,7))
for i,mean_vec in enumerate(mean_vectors):  
    n = X[y==i+1,:].shape[0]
    mean_vec = mean_vec.reshape(7,1) # make column vector
    overall_mean = overall_mean.reshape(7,1) # make column vector
    S_B += n * (mean_vec - overall_mean).dot((mean_vec - overall_mean).T)

print('between-class Scatter Matrix:\n', S_B)
eig_vals, eig_vecs = np.linalg.eig(np.linalg.inv(S_W).dot(S_B))

for i in range(len(eig_vals)):
    eigvec_sc = eig_vecs[:,i].reshape(7,1)   
    print('\nEigenvector {}: \n{}'.format(i+1, eigvec_sc.real))
    print('Eigenvalue {:}: {:.2e}'.format(i+1, eig_vals[i].real))    
for i in range(len(eig_vals)):
    eigv = eig_vecs[:,i].reshape(7,1)
    np.testing.assert_array_almost_equal(np.linalg.inv(S_W).dot(S_B).dot(eigv),
                                         eig_vals[i] * eigv,
                                         decimal=6, err_msg='', verbose=True)
print('ok')  
# Make a list of (eigenvalue, eigenvector) tuples
eig_pairs = [(np.abs(eig_vals[i]), eig_vecs[:,i]) for i in range(len(eig_vals))]

# Sort the (eigenvalue, eigenvector) tuples from high to low
eig_pairs = sorted(eig_pairs, key=lambda k: k[0], reverse=True)

# Visually confirm that the list is correctly sorted by decreasing eigenvalues

print('Eigenvalues in decreasing order:\n')
for i in eig_pairs:
    print(i[0])   
print('Variance explained:\n')
eigv_sum = sum(eig_vals)
for i,j in enumerate(eig_pairs):
    print('eigenvalue {0:}: {1:.2%}'.format(i+1, (j[0]/eigv_sum).real))
W = np.hstack((eig_pairs[0][1].reshape(7,1), eig_pairs[1][1].reshape(7,1)))
print('Matrix W:\n', W.real)
X_lda = X.dot(W)
#assert X_lda.shape == (150,2), "The matrix is not 150x2 dimensional."
from matplotlib import pyplot as plt

def plot_step_lda():

    ax = plt.subplot(111)
    for label,marker,color in zip(
        range(1,4),('^', 's'),('blue', 'red')):

        plt.scatter(x=X_lda[:,0].real[y == label],
                y=X_lda[:,1].real[y == label],
                marker=marker,
                color=color,
                alpha=0.5,
                label=label_dict[label]
                )

    plt.xlabel('LD1')
    plt.ylabel('LD2')

    leg = plt.legend(loc='upper right', fancybox=True)
    leg.get_frame().set_alpha(0.5)
    plt.title('LDA: Merger projection onto the first 2 linear discriminants')

    # hide axis ticks
    plt.tick_params(axis="both", which="both", bottom="off", top="off",  
            labelbottom="on", left="off", right="off", labelleft="on")

    # remove axis spines
    ax.spines["top"].set_visible(False)  
    ax.spines["right"].set_visible(False)
    ax.spines["bottom"].set_visible(False)
    ax.spines["left"].set_visible(False)    

    plt.grid()
    plt.tight_layout
    plt.savefig('../MaNGA_Papers/Paper_I/LDA_plot_img_gyr_'+str(myr)+'.pdf')
plot_pca()
plot_step_lda()
# Out:
# within-class Scatter Matrix:
#  [[  2.6754e-02  -7.1207e-03   6.8705e-02   5.7218e-03   4.5870e-02
#    -1.5775e-01  -1.9437e-04]
#  [ -7.1207e-03   8.0194e-01  -1.2108e+00  -9.4891e-02  -4.2223e-02
#    -1.2290e+00   1.0181e-01]
#  [  6.8705e-02  -1.2108e+00   2.6040e+00   1.0979e-01   1.5654e-01
#     1.3371e+00  -2.2852e-01]
#  [  5.7218e-03  -9.4891e-02   1.0979e-01   4.7258e-02   3.6997e-02
#     4.5803e-01  -6.4080e-03]
#  [  4.5870e-02  -4.2223e-02   1.5654e-01   3.6997e-02   1.1688e-01
#     3.6270e-02   7.1628e-03]
#  [ -1.5775e-01  -1.2290e+00   1.3371e+00   4.5803e-01   3.6270e-02
#     9.6938e+00   2.2049e-01]
#  [ -1.9437e-04   1.0181e-01  -2.2852e-01  -6.4080e-03   7.1628e-03
#     2.2049e-01   1.0251e-01]]
# between-class Scatter Matrix:
#  [[  0.0142   0.0914  -0.4293  -0.0179   0.0257  -0.1997  -0.0446]
#  [  0.0914   0.5888  -2.7645  -0.1152   0.1655  -1.2862  -0.287 ]
#  [ -0.4293  -2.7645  12.9803   0.5408  -0.7771   6.0389   1.3477]
# ...

# %%
for label,marker,color in zip(
        range(1,4),('^', 's'),('blue', 'red')):
    print('label', label)
    print('color', color)
    print(X_lda[:,0].real[y==label])
    print('second comp')
    print(X_lda[:,1].real[y==label])


print(X_lda[:,0].real)

plt.clf()
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(18,10))

for ax,cnt in zip(axes.ravel(), range(0,1)): 
    print('cnt', cnt)

    
    '''min_b = math.floor(np.min(X_lda[:,cnt].real[y==cnt]))
    max_b = math.ceil(np.max(X_lda[:,cnt].real[y==cnt]))
    
    print('min_b,max_b', min_b, max_b)
    
    bins = np.linspace(min_b, max_b, 25)'''
    
    '''for label,marker,color in zip(
        range(1,4),('^', 's'),('blue', 'red')):

        plt.scatter(x=X_lda[:,0].real[y == label],
                y=X_lda[:,1].real[y == label],
                marker=marker,
                color=color,
                alpha=0.5,
                label=label_dict[label]
                )'''
    # plottling the histograms
    for label,col in zip(range(1,4),  ('blue', 'red')):
        
        if cnt==0:
            ax.hist(X_lda[:,0].real[y==label],
                   color=col,
                   label='class %s' %label_dict[label],
                   alpha=0.5,)#bins=bins,
        else:
            ax.hist(X_lda[:,1].real[y==label],
                   color=col,
                   label='class %s' %label_dict[label],
                   alpha=0.5,)#bins=bins,
            
        
    ylims = ax.get_ylim()

    # plot annotation
    leg = ax.legend(loc='upper right', fancybox=True, fontsize=8)
    leg.get_frame().set_alpha(0.5)
    ax.set_ylim([0, max(ylims)+2])
    
    ax.set_xlabel(feature_dict[cnt+5])
    ax.set_title('Histogram #%s' %str(cnt+1))

    # hide axis ticks
    ax.tick_params(axis="both", which="both", bottom="off", top="off",  
            labelbottom="on", left="off", right="off", labelleft="on")

    # remove axis spines
    ax.spines["top"].set_visible(False)  
    ax.spines["right"].set_visible(False)
    ax.spines["bottom"].set_visible(False)
    ax.spines["left"].set_visible(False)    

axes[0].set_ylabel('count')
axes[1].set_ylabel('count')

fig.tight_layout()       

plt.show()
# Out:
# label 1
# color blue
# [ 0.0649  0.1     0.093   0.1102  0.1264  0.088   0.1     0.0922  0.1023
#   0.1068  0.1047  0.0758  0.1096  0.0891]
# second comp
# [-0.9782 -1.226  -1.0409 -1.1485 -1.0779 -1.1286 -1.0157 -1.1408 -1.0496
#  -1.1316 -1.0313 -1.1254 -1.0251 -1.1487]
# label 2
# color red
# [-0.2035 -0.225  -0.1503 -0.2347 -0.1863 -0.1964 -0.2138]
# second comp
# [-1.2061 -1.1981 -1.1796 -1.1393 -0.9138 -1.0191 -0.9781]
# [ 0.0649  0.1    -0.2035  0.093   0.1102 -0.225   0.1264  0.088  -0.1503
#   0.1     0.0922 -0.2347  0.1023  0.1068 -0.1863  0.1047  0.0758 -0.1964
#   0.1096  0.0891 -0.2138]
# cnt 0

# %%
plt.clf()
fig = plt.figure(figsize=(18,10))
ax = fig.add_subplot(111)

for label,col in zip(range(1,4),  ('blue', 'red')):
    ax.hist(X_lda[:,0].real[y==label],
                   color=col,
                   label='class %s' %label_dict[label],
                   alpha=0.5,)#bins=bins,
        
        
ylims = ax.get_ylim()

# plot annotation
leg = ax.legend(loc='upper right', fancybox=True, fontsize=8)
leg.get_frame().set_alpha(0.5)
ax.set_ylim([0, max(ylims)+2])

ax.set_xlabel('LD1', size=20)
ax.set_title('Histogram #%s' %str(cnt+1), size=20)

# hide axis ticks
ax.tick_params(axis="both", which="both", bottom="off", top="off",  
        labelbottom="on", left="off", right="off", labelleft="on")

# remove axis spines
ax.spines["top"].set_visible(False)  
ax.spines["right"].set_visible(False)
ax.spines["bottom"].set_visible(False)
ax.spines["left"].set_visible(False)    

ax.set_ylabel('Count', size=20)
eigvec_sc = eig_vecs[:,1].reshape(7,1) 
print('eig', eigvec_sc)
ax.annotate('Eigenvector 1: ', xy=(0.05,0.9), xycoords='axes fraction', size=20)
ax.annotate(str(eigvec_sc.real), xy=(0.17,0.83), xycoords='axes fraction', size=15)
#axes[1].set_ylabel('count')

fig.tight_layout()       

plt.savefig('../MaNGA_Papers/Paper_I/Hist_Eig1_img_gyr_'+str(myr)+'.pdf')
# Out:
# eig [[ 0.3391+0.j]
#  [-0.1461+0.j]
#  [-0.1337+0.j]
#  [-0.7950+0.j]
#  [ 0.2746+0.j]
#  [ 0.0483+0.j]
#  [-0.3689+0.j]]
